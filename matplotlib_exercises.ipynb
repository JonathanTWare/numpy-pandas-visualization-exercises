# %% [markdown]
# # Use matplotlib to plot the following equation:
#
# y=
# x
# 2
# −
# x
# +
# 2

# %%
import matplotlib.pyplot as plt  


import numpy as np
import math
from random import randint
import random
import pandas as pd

# %% [markdown]
# ### You'll need to write the code that generates the x and y points.

# %%
x = np.linspace(-10, 10, 100)

# %%
y = x**2 - x + 2

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Add an anotation for the point 0, 0, the origin.

# %%
x = np.linspace(-10, 10, 100)
y = x**2 - x + 2
plt.annotate('Origin', xy = (0, .05),xytext=(0, 40), arrowprops = dict(facecolor = 'gray')  )
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# y=
# √
# x
#
# y=
# x
# 3
#
# y=
# 2
# x
#
# y=
# 1
# /
# (
# x
# +
# 1
# )

# %%
import matplotlib.pyplot as plt  


import numpy as np
import math
from random import randint
import random
import pandas as pd



x = x = np.arange(-7, 7)
y1 = np.sqrt(x)
y2 = x**3
y3 = 2 * x
y4 = 1/(x+1)

plt.figure(figsize = (8,8))
plt.subplot(2, 2, 1)
plt.suptitle('Title Here')

plt.subplot(221)
plt.plot(x, y1,color = 'r', ls = '--')


plt.subplot(222)
plt.plot(x, y2,color = 'r', ls = '--', marker = '^')


plt.subplot(223)
plt.plot(x, y3,color = 'g', ls = '--', marker = 'o')

plt.subplot(224)
plt.plot(x, y4,color = 'm', ls = '--', marker = 'v')
plt.axhline(0, color = 'm')

plt.show()
# Out:
# /var/folders/8g/xqsgr3tj7qn4ffm_2xh9lqym0000gn/T/ipykernel_56303/2045984744.py:13: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(x)
# /var/folders/8g/xqsgr3tj7qn4ffm_2xh9lqym0000gn/T/ipykernel_56303/2045984744.py:16: RuntimeWarning: divide by zero encountered in divide
#   y4 = 1/(x+1)

# %% [markdown]
# ### You can use functions from the math module to help implement some of the equations above.

# %% [markdown]
# ### Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
import matplotlib.pyplot as plt  


import numpy as np
import math
from random import randint
import random
import pandas as pd



x = x = np.arange(-7, 7)
y1 = np.sqrt(x)
y2 = x**3
y3 = 2 * x
y4 = 1/(x+1)

plt.figure(figsize = (8,8))
plt.subplot(2, 2, 1)
plt.suptitle('Title Here')

plt.subplot(221)
plt.plot(x, y1,color = 'r', ls = '--')


plt.subplot(222)
plt.plot(x, y2,color = 'r', ls = '--', marker = '^')


plt.subplot(223)
plt.plot(x, y3,color = 'g', ls = '--', marker = 'o')

plt.subplot(224)
plt.plot(x, y4,color = 'm', ls = '--', marker = 'v')
plt.axhline(0, color = 'm')

plt.show()
# Out:
# /var/folders/8g/xqsgr3tj7qn4ffm_2xh9lqym0000gn/T/ipykernel_56303/2045984744.py:13: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(x)
# /var/folders/8g/xqsgr3tj7qn4ffm_2xh9lqym0000gn/T/ipykernel_56303/2045984744.py:16: RuntimeWarning: divide by zero encountered in divide
#   y4 = 1/(x+1)

# %% [markdown]
# ### Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
import matplotlib.pyplot as plt  


import numpy as np
import math
from random import randint
import random
import pandas as pd



x = x = np.arange(-7, 7)
y1 = np.sqrt(x)
y2 = x**3
y3 = 2 * x
y4 = 1/(x+1)

plt.figure(figsize = (8,8))
plt.subplot(2, 2, 1)
plt.suptitle('Title Here')

plt.subplot(221)
plt.plot(x, y1,color = 'r', ls = '--')


plt.subplot(222)
plt.plot(x, y2,color = 'r', ls = '--', marker = '^')


plt.subplot(223)
plt.plot(x, y3,color = 'g', ls = '--', marker = 'o')

plt.subplot(224)
plt.plot(x, y4,color = 'm', ls = '--', marker = 'v')
plt.axhline(0, color = 'm')

plt.show()
# Out:
# /var/folders/8g/xqsgr3tj7qn4ffm_2xh9lqym0000gn/T/ipykernel_56303/2045984744.py:13: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(x)
# /var/folders/8g/xqsgr3tj7qn4ffm_2xh9lqym0000gn/T/ipykernel_56303/2045984744.py:16: RuntimeWarning: divide by zero encountered in divide
#   y4 = 1/(x+1)
